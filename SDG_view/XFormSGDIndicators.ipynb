# %%
import numpy as np
import pandas as pd
pd.__version__
# Out:
# u'0.20.1'

# %% [markdown]
# Create Indicators table

# %%
data = pd.read_csv('sdg.csv')
df2 = data.T

df2.to_csv('sdgIndicators_step1.csv', header=False)

# %% [markdown]
# Create Summary by Goal

# %%
#Not used

df1a = data.iloc[:,217]
df1b = data.iloc[:,19:22]
df1 = pd.concat([df1a, df1b], axis=1)
#df1.to_csv('goal1.csv', header = True)

# %% [markdown]
# Create Vertical Table

# %%
df2 = pd.read_csv('sdgIndicators_step1.csv')
countries = data['country']
add_country = False
df_indicator = df2.iloc[19:118,0]
df_sdg = df_indicator.str.extract('([\w\-]+)')

for country in countries:
    df_c = df2[country]
    df_score = df_c.iloc[19:118]
    df_country = pd.DataFrame({'country': country , 'SDG': df_sdg, 'indicator': df_indicator, 'score':df_score})
    if add_country == True: 
        df_final = df_final.append(df_country, ignore_index=True)
    else:
        df_final = df_country
        add_country = True
# Out:
# /Users/mona/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:6: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)

# %%
# Write to csv file

df_final.to_csv('sdgIndicators_vertical.csv', header=True)

# %%
df_final
# Out:
#       SDG      country                                          indicator  \
# 0       1  Afghanistan               1 - [OECD-only] Poverty line 50% (%)
# 1       1  Afghanistan  1 - Projected poverty headcount ratio at $1.90...
# 2       1  Afghanistan       1 - Poverty headcount ratio at $1.90/day (%)
# 3       2  Afghanistan                            2 - Cereal yield (t/ha)
# 4       2  Afghanistan          2 - Sust. Nitrogen Management Index (0-1)
# 5       2  Afghanistan                2 - Prevalence of adult obesity (%)
# 6       2  Afghanistan           2 - Prevalence of stunting, under-5s (%)
# 7       2  Afghanistan             2 - Prevalence of undernourishment (%)
# 8       2  Afghanistan            2 - Prevalence of wasting, under-5s (%)
# 9       3  Afghanistan  3 - Births attended by skilled health personne...
# 10      3  Afghanistan        3 - Adolescent fertility (births per 1,000)
# 11      3  Afghanistan       3 - Healthy life expectancy at birth (years)
# ...
